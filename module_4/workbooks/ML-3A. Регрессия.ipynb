# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
myData = pd.read_csv('mycar.csv', encoding='utf-16')

# %%
myData.head()
# Out:
#    Speed  Stopping_dist
# 0      4              2
# 1      4             10
# 2      7              4
# 3      7             22
# 4      8             16

# %%
myData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
# Speed            49 non-null int64
# Stopping_dist    49 non-null int64
# dtypes: int64(2)
# memory usage: 912.0 bytes

# %%
X = myData.iloc[:,:-1].values
Y = myData.iloc[:,1].values

# %%
X
# Out:
# array([[ 4],
#        [ 4],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [10],
#        [10],
#        [11],
#        [11],
#        [12],
#        [12],
#        [12],
#        [12],
#        [13],
#        [13],
#        [13],
#        [13],
#        [14],
#        [14],
#        [14],
#        [14],
#        [15],
#        [15],
#        [15],
#        [16],
#        [16],
#        [17],
#        [17],
#        [17],
#        [18],
#        [18],
#        [18],
#        [18],
#        [19],
#        [19],
#        [19],
#        [20],
#        [20],
#        [20],
#        [20],
#        [20],
#        [22],
#        [23],
#        [24],
#        [24],
#        [24],
#        [25]], dtype=int64)

# %%
Y
# Out:
# array([ 2, 10,  4, 22, 16, 10, 18, 26, 34, 17, 28, 14, 20, 24, 28, 26, 34,
#        34, 46, 26, 36, 60, 80, 20, 26, 54, 32, 40, 32, 40, 50, 42, 56, 76,
#        84, 36, 46, 68, 32, 48, 52, 56, 64, 66, 54, 70, 92, 93, 85],
#       dtype=int64)

# %%
plt.plot(myData)

# %%
plt.plot(X,Y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.3)

# %%
X_train.shape
# Out:
# (34, 1)

# %%
X_test.shape
# Out:
# (15, 1)

# %%
Y_train.shape
# Out:
# (34,)

# %%
Y_train
# Out:
# array([26, 64, 50, 26, 32, 28, 34, 26, 32, 10, 80, 92, 42, 76, 36, 66, 18,
#        60, 24, 32, 22, 84, 46, 40, 85,  4, 14, 17, 34, 54, 48, 40, 52, 46],
#       dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
myModel = LinearRegression() #Обозначаем, что наша модель - линейная регрессия
myModel.fit(X_train,Y_train) #обучаем модель на обучающих данных
# Out:
# LinearRegression()

# %%
y_pred = myModel.predict(X_test)
y_pred
# Out:
# array([38.47847878, 42.03879558, 74.08164671, 20.67689482, 17.11657803,
#         2.87531086, 27.79752841, 74.08164671, 52.71974595, 31.3578452 ,
#        59.84037954, 70.52132992, 56.28006275, 56.28006275, 34.91816199])

# %%
y_happy = [4,20,110,15,23]

# %%
y_happy_pred = [5,15,100,9,21]

# %%
from sklearn import metrics  # подгружаем метрики

# %%
#Вычисляем MAE:

MAE = metrics.mean_absolute_error(y_happy, y_happy_pred)

print(MAE)
# Out:
# 4.8

# %%
#Вычисляем MSE:

MSE = metrics.mean_squared_error(y_happy, y_happy_pred)
print(MSE)
# Out:
# 33.2

# %%
#Вычисляем коэффициент детерминации:

R_2 = metrics.r2_score(y_happy, y_happy_pred)
print(R_2)
# Out:
# 0.9774247946472284

# %%
data = pd.read_csv('data_flats.csv', sep =';')
data.head()
# Out:
#    id  full_sq  life_sq  floor  preschool_education_centers_raion  \
# 0   1       43     27.0    4.0                                  5
# 1   2       34     19.0    3.0                                  5
# 2   3       43     29.0    2.0                                  4
# 3   4       89     50.0    9.0                                  9
# 4   5       77     77.0    4.0                                  7
#
#    school_education_centers_raion  school_education_centers_top_20_raion  \
# 0                               5                                      0
# 1                               8                                      0
# 2                               7                                      0
# 3                              10                                      0
# 4                               9                                      0
#
#    university_top_20_raion  sport_objects_raion  additional_education_raion  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30469 entries, 0 to 30468
# Data columns (total 21 columns):
# id                                       30469 non-null int64
# full_sq                                  30469 non-null int64
# life_sq                                  24086 non-null float64
# floor                                    30302 non-null float64
# preschool_education_centers_raion        30469 non-null int64
# school_education_centers_raion           30469 non-null int64
# school_education_centers_top_20_raion    30469 non-null int64
# university_top_20_raion                  30469 non-null int64
# sport_objects_raion                      30469 non-null int64
# additional_education_raion               30469 non-null int64
# culture_objects_top_25_raion             30469 non-null int64
# shopping_centers_raion                   30469 non-null int64
# metro_km_walk                            30444 non-null float64
# ...

# %%
data.isnull().sum()
# Out:
# id                                          0
# full_sq                                     0
# life_sq                                  6383
# floor                                     167
# preschool_education_centers_raion           0
# school_education_centers_raion              0
# school_education_centers_top_20_raion       0
# university_top_20_raion                     0
# sport_objects_raion                         0
# additional_education_raion                  0
# culture_objects_top_25_raion                0
# shopping_centers_raion                      0
# metro_km_walk                              25
# kindergarten_km                             0
# school_km                                   0
# park_km                                     0
# green_zone_km                               0
# mkad_km                                     0
# bulvar_ring_km                              0
# kremlin_km                                  0
# ...

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(20,12))
sns_heatmap = sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
data.price_doc.hist()

# %%
data['price_doc'] = data['price_doc'].apply(lambda w: np.log(w + 1))
data.price_doc.hist()

# %%
sns.set(font_scale=1)
plt.subplots(figsize=(12, 12))
sns.heatmap(data.corr(), square=True,
              annot=True, fmt=".1f", linewidths=0.1, cmap="RdBu")

# %%
#удаляем ненужные признаки
data.drop(['preschool_education_centers_raion', 'kindergarten_km', 'park_km', 'kremlin_km', 'life_sq'], axis = 1, 
          inplace = True)

# %%
data.isna().sum()
# Out:
# id                                         0
# full_sq                                    0
# floor                                    167
# school_education_centers_raion             0
# school_education_centers_top_20_raion      0
# university_top_20_raion                    0
# sport_objects_raion                        0
# additional_education_raion                 0
# culture_objects_top_25_raion               0
# shopping_centers_raion                     0
# metro_km_walk                             25
# school_km                                  0
# green_zone_km                              0
# mkad_km                                    0
# bulvar_ring_km                             0
# price_doc                                  0
# dtype: int64

# %%
# удаляем все строчки, в которых есть пропуски
data.dropna(axis = 0, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30277 entries, 0 to 30468
# Data columns (total 16 columns):
# id                                       30277 non-null int64
# full_sq                                  30277 non-null int64
# floor                                    30277 non-null float64
# school_education_centers_raion           30277 non-null int64
# school_education_centers_top_20_raion    30277 non-null int64
# university_top_20_raion                  30277 non-null int64
# sport_objects_raion                      30277 non-null int64
# additional_education_raion               30277 non-null int64
# culture_objects_top_25_raion             30277 non-null int64
# shopping_centers_raion                   30277 non-null int64
# metro_km_walk                            30277 non-null float64
# school_km                                30277 non-null float64
# green_zone_km                            30277 non-null float64
# ...

# %%
# выделяем матрицу признаков и целевую переменную
X = data.iloc[:,1:-1].values
y = data.iloc[:,-1].values

# %%
X.shape
# Out:
# (30277, 14)

# %%
y.shape
# Out:
# (30277,)

# %%
from sklearn.model_selection import train_test_split

# %%
# выделяем обучающую и тестовую выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state = 77)

# %%
#импортируем модуль нормализации
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

# %%
# Нормализуем признаки
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
myModel = LinearRegression() #Обозначаем, что наша модель - линейная регрессия
myModel.fit(X_train_norm,y_train) #обучаем модель на обучающих данных
# Out:
# LinearRegression()

# %%
y_pred = myModel.predict(X_test_norm)

# %%
# возвращаем зависимую переменную в изначальный вид
y_pred = np.exp(y_pred)
y_test = np.exp(y_test)

# %%
from sklearn import metrics  # подгружаем метрики
#Вычисляем MSE:

MSE = metrics.mean_squared_error(y_test, y_pred)
print(round(MSE))
# Out:
# 16647931507747.0

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt

# %%
data = load_boston

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-6208d269f320> in <module>
# ----> 1 data.info()
#
# AttributeError: 'function' object has no attribute 'info'

# %%
X, y = data['data'], data['target']

X = np.hstack([np.ones(X.shape[0])[:, np.newaxis], X])

theta = linreg_linear(X, y)

# %%
y_true = [1.23, 2.35, 2.75]
y_pred = [1.01, 12.3, 2.74]

# %%
RMSE = np.sqrt(metrics.mean_squared_error(y_true, y_pred))
print(round((RMSE),2))
# Out:
# 5.75
